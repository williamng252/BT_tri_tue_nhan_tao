# %% [markdown]
# # BÀI TẬP TRÍ TUỆ NHÂN TẠO
# **Họ và tên:** Nguyễn Anh Quân
# **Mã sinh viên:** 24110309
#
# Dưới đây là link GitHub chứa bài tập của em:
# https://github.com/williamng252/BT_tri_tue_nhan_tao.git
